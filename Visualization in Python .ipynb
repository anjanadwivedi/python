# %%
#visualization library in Python for 2D plots of arrays.
#allows visual access to huge amounts of data in easily digestible visuals.
#Matplotlib consists of several plots like line, bar, scatter, histogram etc
#Matplotlib comes with a wide variety of plots. 
#Plots helps to understand trends, patterns, and to make correlations. 
#They are typically instruments for reasoning about quantitative information
#Line plot :
#importing matplotlib module 
import matplotlib.pyplot as plt

#x-axis values
x=[2, 4, 6, 8, 10]

#y-axis values
y=[10, 20, 30, 40, 50]

#Function to plot
plt.plot(x,y, label='linear')
# Add a legend
plt.legend()
#Function to show the plot
plt.show()

# %%
#Bar plot :
#importing matplot lib module
import matplotlib.pyplot as plt

#x-axis values
x=[2, 4, 6, 8, 10]

#y-axis values
y=[10, 20, 30, 40, 50]
# Function to plot the bar 
plt.bar(x,y,label='bar graph')
plt.legend()
# function to show the plot 
plt.show()

# %%
#Histogram :
# importing matplotlib module 
import matplotlib.pyplot as plt
#x-axis values
#x-axis values
x=[2, 4, 6, 8, 10]

#y-axis values
y=[10, 20, 30, 40, 50]
plt.hist(x)
plt.show()

# %%
#scatter plot
import matplotlib.pyplot as plt
#x-axis values
x=[2, 4, 6, 8, 10]

#y-axis values
y=[10, 20, 30, 40, 50]
plt.scatter(x,y)
plt.show()

# %%
# we can turn off the axis and display 
# only the line by passing the  
# optional parameter 'off' to it 

import matplotlib.pyplot as plt
#x-axis values
x=[2, 4, 6, 8, 10]

#y-axis values
y=[10, 20, 30, 40, 50]

#Function to plot
plt.plot(x,y, label='linear')
# Add a legend
plt.legend()
plt.axis('off') 
#Function to show the plot
plt.show()

# %%
#This function is used to set some axis properties to the graph.


#Syntax: matplotlib.pyplot.axis(*args, emit=True, **kwargs)

#Parameters:
#xmin, xmax, ymin, ymax:These parameters can be used to
#set the axis limits on the graph
#emit:Its a bool value used to notify observers of the axis limit change
import matplotlib.pyplot as plt 
  
x =[1, 2, 3, 4, 5] 
y =[2, 4, 6, 8, 10] 
  
# Plotting the graph 
plt.plot(x, y) 
  
# Setting the x-axis to 1-10 
# and y-axis to 1-15 
plt.axis([0, 10, 1, 15]) 

# Showing the graph with updated axis 
plt.show()

# %%
import numpy as np
print(np.random.seed(444))
# Out:
# None

# %%
import matplotlib.pyplot as plt 
import numpy as np
# Prepare the data
x = np.linspace(0, 10, 100)
y=np.random.normal(100,1,100) 
#print(x)
plt.scatter(x,y)
plt.show()

# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data
x = np.linspace(0, 10, 100)

# Plot the data
plt.plot(x, x, label='linear')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
a=[1,2,3,4,5]
b=[6,7,8,9,10]

#plt.bar(a,b)
plt.plot(a,b)


plt.plot(a,b,'o',color='black')
plt.plot(a,marker='D',ms=25,color='Violet')
plt.plot(b,marker='H',ms=25,color='Pink')
#plt.plot(b,marker='D',ms=40,color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt
a=['A','B','C','E','F']
b=[5,6,7,8,9]

#plt.barh(a,b)
plt.barh(a,b,color ='orange')

plt.show()

# %%
import matplotlib.pyplot as plt
a=[1,2,3,4,5]
b=[4,6,5,8,9]

#plt.plot(a,b,) --line chart
#plt.plot(a,b,'o') #dot 
#plt.plot(a,'o')
#plt.plot(a,marker='o')
#plt.plot(b,marker='*')
#plt.plot(a,marker='o',ms=40,color='red')
#plt.plot(b,marker='D',ms=40,color='blue')
#plt.plot(a,marker='H',ms=25,mfc='Black',color='pink',ls='-')
#plt.plot(b,marker='D',ms=25,mec='R',color='orange',ls='-')

x=['A','B','C','D','E','F']
y=[10,20,30,40,50,60]
#plt.bar(x,y)
plt.barh(x,y,height='0.5',color ='orange')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(100,1,100) 
print(x)

plt.hist(x)
plt.show()
# Out:
# [101.54217468 100.83312223 101.27733979  99.28570742  99.8730534
#  101.11199648 100.80743016  99.95518995  99.68808495  98.87835586
#   99.11065115 100.63304583  98.76035688  99.65003109  98.97080417
#  101.42511905 100.92027733  99.52714194  99.94147512 100.15116825
#   98.31184001  99.79854593  99.35934245 101.55684717  99.4764387
#   98.34666624  99.26077601 100.47825527  99.27112269 101.42614572
#   99.44338124 100.56766856 100.86935294 101.12590297 100.69682378
#   98.81462463  98.89259157 101.13069338 101.7687696  100.58857992
#  100.05028108  97.93594782 101.02656385  99.36697187 100.03481332
#   99.80788374  99.72952149 101.16823574 100.12595133  98.72024486
#   98.46752802 100.44908376  99.26820823 101.93291643 100.40697441
#  102.04780396  99.13632029 100.52513334 101.3713273   99.91263287
#  100.70527496 100.16765019  99.65191318  97.7944461  101.09992892
#  100.36559291  99.89347758  98.98531891 100.00477262  97.72117018
# ...

# %%
print(ord('H'))
print(ord('h'))
# Out:
# 72
# 104
