# %%
#loading insurance.csv file

import pandas as pd
ins= pd.read_csv("insurance.csv")
ins

#print(type(ins))
print(type(ins))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#First 5 rows in DataFrame
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Last 5 rows in DataFrame
ins.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#the number of rows and columns present in the dataset

ins.shape
# Out:
# (1338, 7)

# %%
#mean

ins.mean()
# Out:
# age            39.207025
# bmi            30.663397
# children        1.094918
# charges     13270.422265
# dtype: float64

# %%
#median

ins.median()
# Out:
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
#standard Deviation
ins.std()
# Out:
# age            14.049960
# bmi             6.098187
# children        1.205493
# charges     12110.011237
# dtype: float64

# %%
#Min
ins.min()
# Out:
# age                18
# sex            female
# bmi             15.96
# children            0
# smoker             no
# region      northeast
# charges       1121.87
# dtype: object

# %%
#Max
ins.max()
# Out:
# age                64
# sex              male
# bmi             53.13
# children            5
# smoker            yes
# region      southwest
# charges       63770.4
# dtype: object

# %%
#count
print(type(ins.max()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
d=ins.rename(columns={'bmi':'Body_Mass_Index'})
d
# Out:
#       age     sex  Body_Mass_Index  children smoker     region      charges
# 0      19  female           27.900         0    yes  southwest  16884.92400
# 1      18    male           33.770         1     no  southeast   1725.55230
# 2      28    male           33.000         3     no  southeast   4449.46200
# 3      33    male           22.705         0     no  northwest  21984.47061
# 4      32    male           28.880         0     no  northwest   3866.85520
# 5      31  female           25.740         0     no  southeast   3756.62160
# 6      46  female           33.440         1     no  southeast   8240.58960
# 7      37  female           27.740         3     no  northwest   7281.50560
# 8      37    male           29.830         2     no  northeast   6406.41070
# 9      60  female           25.840         0     no  northwest  28923.13692
# 10     25    male           26.220         0     no  northeast   2721.32080
# ...

# %%
#Pandas dataframe.corr() is used to find the pairwise correlation of all columns in the dataframe.
#Any na values are automatically excluded. For any non-numeric data type columns in the dataframe it is ignored.

#Find correlation between age children and charges

d.corr(method ='pearson')
# Out:
#                       age  Body_Mass_Index  children   charges
# age              1.000000         0.109272  0.042469  0.299008
# Body_Mass_Index  0.109272         1.000000  0.012759  0.198341
# children         0.042469         0.012759  1.000000  0.067998
# charges          0.299008         0.198341  0.067998  1.000000

# %%
d.corr(method ='kendall')
# Out:
#                       age  Body_Mass_Index  children   charges
# age              1.000000         0.073273  0.043253  0.475302
# Body_Mass_Index  0.073273         1.000000  0.011562  0.082524
# children         0.043253         0.011562  1.000000  0.103107
# charges          0.475302         0.082524  0.103107  1.000000

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
#From entire insurance dataframe extract all rows from row number 500 to row number 1000
#inst=ins.iloc[500:1000]

#Extract sex children region  columns

insurance_random_set=inst[["sex", "children", "region"]]
insurance_random_set
# Out:
#          sex  children     region
# 0     female         0  southwest
# 1       male         1  southeast
# 2       male         3  southeast
# 3       male         0  northwest
# 4       male         0  northwest
# 5     female         0  southeast
# 6     female         1  southeast
# 7     female         3  northwest
# 8       male         2  northeast
# 9     female         0  northwest
# 10      male         0  northeast
# 11    female         0  southeast
# 12      male         0  southwest
# 13    female         0  southeast
# 14      male         0  southeast
# 15      male         1  southwest
# 16    female         1  northeast
# 17      male         0  northeast
# 18      male         0  southwest
# 19      male         0  southwest
# 20    female         0  northeast
# 21    female         1  southwest
# 22      male         0  southeast
# 23    female         1  northeast
# 24      male         2  northwest
# 25    female         3  southeast
# ...

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
#Extract sex children region  columns
#store result in insurance_random_set
# Out:
#       age     sex     bmi  children smoker     region       charges
# 335    64    male  34.500         0     no  southwest  13822.803000
# 603    64  female  39.050         3     no  southeast  16085.127500
# 752    64    male  37.905         0     no  northwest  14210.535950
# 1265   64    male  23.760         0    yes  southeast  26926.514400
# 534    64    male  40.480         0     no  southeast  13831.115200
# 328    64  female  33.800         1    yes  southwest  47928.030000
# 768    64  female  39.700         0     no  southwest  14319.031000
# 1241   64    male  36.960         2    yes  southeast  49577.662400
# 62     64    male  24.700         1     no  northwest  30166.618170
# 801    64  female  35.970         0     no  southeast  14313.846300
# 825    64  female  31.825         2     no  northeast  16069.084750
# 378    64  female  30.115         3     no  northwest  16455.707850
# 398    64    male  25.600         2     no  southwest  14988.432000
# ...

# %%
#sort insurance dataframe in descending order of age

a=ins.sort_values('age',ascending=False)
print(a)
# Out:
#       age     sex     bmi  children smoker     region       charges
# 335    64    male  34.500         0     no  southwest  13822.803000
# 603    64  female  39.050         3     no  southeast  16085.127500
# 752    64    male  37.905         0     no  northwest  14210.535950
# 1265   64    male  23.760         0    yes  southeast  26926.514400
# 534    64    male  40.480         0     no  southeast  13831.115200
# 328    64  female  33.800         1    yes  southwest  47928.030000
# 768    64  female  39.700         0     no  southwest  14319.031000
# 1241   64    male  36.960         2    yes  southeast  49577.662400
# 62     64    male  24.700         1     no  northwest  30166.618170
# 801    64  female  35.970         0     no  southeast  14313.846300
# 825    64  female  31.825         2     no  northeast  16069.084750
# 378    64  female  30.115         3     no  northwest  16455.707850
# 398    64    male  25.600         2     no  southwest  14988.432000
# ...

# %%
t=ins[ins.age !=18]
t
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# 13     56  female  39.820         0     no  southeast  11090.71780
# ...

# %%
ins.iloc[500:1000]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 500   29    male  34.400         0    yes  southwest  36197.69900
# 501   43    male  26.030         0     no  northeast   6837.36870
# 502   51    male  23.210         1    yes  southeast  22218.11490
# 503   19    male  30.250         0    yes  southeast  32548.34050
# 504   38  female  28.930         1     no  southeast   5974.38470
# 505   37    male  30.875         3     no  northwest   6796.86325
# 506   22    male  31.350         1     no  northwest   2643.26850
# 507   21    male  23.750         2     no  northwest   3077.09550
# 508   24  female  25.270         0     no  northeast   3044.21330
# 509   57  female  28.700         0     no  southwest  11455.28000
# 510   56    male  32.110         1     no  northeast  11763.00090
# 511   27    male  33.660         0     no  southeast   2498.41440
# 512   51    male  22.420         0     no  northeast   9361.32680
# ...

# %%
#From entire insurance dataframe extract all rows from row number 500 to row number 1000
ins_tmp=ins.iloc[500:1000]

#Extract sex children region  columns

insurance_random_set=ins_tmp[["sex", "children", "region"]]
insurance_random_set
# Out:
#         sex  children     region
# 500    male         0  southwest
# 501    male         0  northeast
# 502    male         1  southeast
# 503    male         0  southeast
# 504  female         1  southeast
# 505    male         3  northwest
# 506    male         1  northwest
# 507    male         2  northwest
# 508  female         0  northeast
# 509  female         0  southwest
# 510    male         1  northeast
# 511    male         0  southeast
# 512    male         0  northeast
# 513    male         0  southwest
# 514    male         1  southwest
# 515    male         0  southwest
# 516    male         1  southeast
# 517    male         2  northwest
# 518  female         1  southwest
# 519    male         0  northeast
# 520  female         0  northeast
# 521  female         0  southeast
# 522  female         0  northeast
# 523  female         0  southeast
# 524    male         1  southeast
# 525  female         0  southeast
# 526  female         2  northwest
# ...
